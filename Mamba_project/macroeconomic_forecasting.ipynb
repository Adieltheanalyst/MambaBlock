# %%
import pandas

# %%
import requests

# %%
import torch

# %%
import requests 
import pandas as pd 
import numpy as np
import json
import time 
import os 
from pathlib import Path

# %%
COUNTRIES= [
    "KEN", "TZA", "UGA", "ETH","RWA", # East Africa
    "NGA","GHA", "CIV","SEN", #west africa
    "EGY","MAR", "TUN", #north africa
    "ZAF", "BWA","ZMB" #southern Africa
    ,"USA","GBR","DEU","FRA","JPN" # major economies
    ,"CHN","IND","BRA","MEX","TUR"
    ,"TUR","THA","MYS","PHL","VNM",# upcoming economies
    "SAU","ARE","NOR","AUS","CAN" # commodity exporters
    "POL","CZE","HUN","ROU", # Eastern Europe
    "ARG","CHL","COL","PER",# Latin America
    "KOR", "SGP", "PAK","BGD" # other asia
    ,"ISL", "NZL","CRI"
]

INDICATORS= {
    "NY.GDP.MKTP.KD.ZG": "gdp_growth",
    "FP.CPI.TOTL.ZG": "inflation",
    "SL.UEM.TOTL.ZS": "unemployment",
    "FR.INR.LEND": "lending_rate",
    "NE.TRD.GFS.ZS": "trade_opennes",
    "BN.CAB.XOKA.GD.ZS": "govt_debt",
    "NY.GDP.PCAP.KD.ZG": "gdp_per_capita_growth"
}

START_YEAR= 1995
END_YEAR=2023
RAW_PATH = Path("data/raw/wb_raw.csv")
PROCESSED_PATH=Path("data/processed/panel.csv")
TENSOR_PATH= Path("data/processed/tensor.npy")
META_PATH = Path("data/processed/metadata.json")
